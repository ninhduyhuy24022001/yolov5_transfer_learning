# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/DeepLearning/ComputerVision/yolo_transfer
# !ls
# link: https://kikaben.com/yolov5-transfer-learning-dogs-cats/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DeepLearning/ComputerVision/yolo_transfer
# cats_and_dogs.yaml  download		sample_test  transfer.ipynb  yolov5s.pt
# data		    prepare_data.ipynb	test.ipynb   yolov5

# %%
# !pip install -q -U -r yolov5/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 59.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 31.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 51.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.0/804.0 kB 31.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 26.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.0 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.0 which is incompatible.

# %%
# Đánh giá mô hình trên tập test

# !python yolov5/val.py --data cats_and_dogs.yaml --weights yolov5/runs/train/exp/weights/best.pt --task test
# Out:
# val: data=cats_and_dogs.yaml, weights=['yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-187-g0004c74 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 14.5MB/s]
# test: Scanning /content/drive/MyDrive/DeepLearning/ComputerVision/yolo_transfer/data/labels/test.cache... 398 images, 0 backgrounds, 0 corrupt: 100% 398/398 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [04:09<00:00, 19.23s/it]
#                    all        398        441      0.675      0.813      0.788      0.492
#                    cat        398        206      0.704      0.791      0.797      0.457
#                    dog        398        235      0.646      0.834       0.78      0.526
# Speed: 6.4ms pre-process, 596.7ms inference, 0.9ms NMS per image at shape (32, 3, 640, 640)
# Results saved to yolov5/runs/val/exp2

# %%
# Đánh giá mô hình trên tập test

# !python yolov5/val.py --data cats_and_dogs.yaml --weights yolov5/runs/train/exp2/weights/best.pt --task test
# Out:
# val: data=cats_and_dogs.yaml, weights=['yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-187-g0004c74 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/DeepLearning/ComputerVision/yolo_transfer/data/labels/test.cache... 398 images, 0 backgrounds, 0 corrupt: 100% 398/398 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [04:15<00:00, 19.62s/it]
#                    all        398        441      0.726      0.846      0.824      0.602
#                    cat        398        206      0.771       0.85      0.856       0.61
#                    dog        398        235       0.68      0.843      0.792      0.594
# Speed: 8.9ms pre-process, 619.5ms inference, 0.9ms NMS per image at shape (32, 3, 640, 640)
# Results saved to yolov5/runs/val/exp3

# %%
import os

print("Số lượng mẫu trong tập huấn luyện (train):", len(os.listdir("data/images/train")))
print("Số lượng mẫu trong tập kiểm định (validation):",len(os.listdir("data/images/val")))
print("Số lượng mẫu trong tập kiểm thử (test):", len(os.listdir("data/images/test")))

print("Số lượng mẫu trong tập huấn luyện (train):", len(os.listdir("data/labels/train")))
print("Số lượng mẫu trong tập kiểm định (validation):",len(os.listdir("data/labels/val")))
print("Số lượng mẫu trong tập kiểm thử (test):", len(os.listdir("data/labels/test")))
# Out:
# Số lượng mẫu trong tập huấn luyện (train): 3176
# Số lượng mẫu trong tập kiểm định (validation): 396
# Số lượng mẫu trong tập kiểm thử (test): 398
# Số lượng mẫu trong tập huấn luyện (train): 3176
# Số lượng mẫu trong tập kiểm định (validation): 396
# Số lượng mẫu trong tập kiểm thử (test): 398
